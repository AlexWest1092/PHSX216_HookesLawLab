# %% [markdown]
# # Method 1:  Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
m1 = np.array([.1,.05,.15,.2,.5,.3])
x1 = np.array([.34,.18,.5,.67,.83,.99])
errm = np.array([.001,.001,.001,.001,.001,.001])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x1,m1*9.8,errm*9.8,'Small k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 4.31 N/m
# Error in slope = 0.01 N/m
# Goodness of fit = 43803.01

# %%
import physplot as phys
import numpy as np

#spring 2
m2 = np.array([.05,.1,.15,.2,.5,.3])
x2 = np.array([.06,.1,.14,.18,.22,.26])
errm2 = np.array([.001,.001,.001,.001,.001,.001])

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(x2,m2*9.8,errm2*9.8,'Large k spring','x(m)','F(N)','N/m')
# Out:
# Slope = 17.50 N/m
# Error in slope = 0.06 N/m
# Goodness of fit = 44047.62

# %% [markdown]
# # Method 2: Determine k for spring 1 and 2

# %%
import physplot as phys
import numpy as np

#spring 1
Tsq1 = np.array([3.877,3.247,2.602,1.963,1.302,.653])
m1 = np.array([.3,.25,.2,.15,.1,.05])
errm1 = np.array([.001,.001,.001,.001,.001,.001])

#.039,.036,.032,.028,.023,.016

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,Tsq1,errm1,'Small k spring','m(kg)','T^2(s^2)','m/N')
# Out:
# Slope = 12.91 m/N
# Error in slope = 0.00 m/N
# Goodness of fit = 370.34

# %%
import physplot as phys
import numpy as np

#spring 1
Tsq1 = np.array([.98,.81,.65,.49,.33,.16])
m1 = np.array([.3,.25,.2,.15,.1,.05])
errm1 = np.array([.001,.001,.001,.001,.001,.001])

#.039,.036,.032,.028,.023,.016

#call the plotfit function from the physplot.py code
#You can open that code to see how it works
#This is what the plotfit function looks like.  Pass
#in the parameters in the correct order
#plotfit(x,y,dy,title,xlabel,ylabel,slopeunit)

phys.plotfit(m1,Tsq1,errm1,'Small k spring','m(kg)','T^2(s^2)','m/N')
# Out:
# Slope = 3.26 m/N
# Error in slope = 0.00 m/N
# Goodness of fit = 57.14
